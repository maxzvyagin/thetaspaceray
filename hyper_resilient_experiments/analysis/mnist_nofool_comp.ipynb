# %% [markdown]
# ### Comparing NoFool to Normal MNIST

# %%
import pandas as pd

# %%
mnist = pd.read_csv("../singularity_singlegpu_mnist_10trials_11-13_fixed.csv")

# %%
no_fool = pd.read_csv("../singularity_singlegpu_mnist-nofool_10trials_11-13_fixed.csv")

# %%
len(mnist)
# Out:
# 60

# %%
len(no_fool)
# Out:
# 140

# %%
no_fool.head()
# Out:
#    trial_id  pt_test_acc  tf_test_acc  average_res  time_this_iter_s  done  \
# 0  c2e1b62c     0.657469       0.6700     0.663734          0.007899  True
# 1  c30609aa     0.900028       0.9112     0.905614          0.006450  True
# 2  c3093198     0.865802       0.8903     0.878051          0.009371  True
# 3  c30b0bbc     0.667911       0.6918     0.679855          0.008520  True
# 4  c30cc57e     0.774563       0.7160     0.745282          0.008483  True
#
#    timesteps_total  episodes_total  training_iteration  \
# 0              NaN             NaN                   2
# 1              NaN             NaN                   2
# 2              NaN             NaN                   2
# 3              NaN             NaN                   2
# 4              NaN             NaN                   2
#
#                       experiment_id  ...    hostname        node_ip  \
# 0  75cb53aacfc845709020722f6c14d1d6  ...  thetagpu13  140.221.68.23
# ...

# %%
no_fool_sorted = no_fool.sort_values('average_res', ascending=False)
no_fool_sorted = no_fool_sorted.reset_index(drop=True)

# %%
mnist_sorted = mnist.sort_values('average_res', ascending=False)
mnist_sorted = mnist_sorted.reset_index(drop=True)

# %%
no_fool_sorted.head()
# Out:
#    trial_id  pt_test_acc  tf_test_acc  average_res  time_this_iter_s  done  \
# 0  d737008a     0.979507       0.9813     0.980403          0.007831  True
# 1  fca574e4     0.979464       0.9804     0.979932          0.007350  True
# 2  fca3656e     0.977771       0.9805     0.979136          0.030291  True
# 3  5ff34eb0     0.978792       0.9775     0.978146          0.008665  True
# 4  c49ab616     0.973692       0.9776     0.975646          0.008765  True
#
#    timesteps_total  episodes_total  training_iteration  \
# 0              NaN             NaN                   2
# 1              NaN             NaN                   2
# 2              NaN             NaN                   2
# 3              NaN             NaN                   2
# 4              NaN             NaN                   2
#
#                       experiment_id  ...    hostname        node_ip  \
# 0  ed8860162f414ae4a83f83a03d0d8b09  ...  thetagpu13  140.221.68.23
# ...

# %%
mnist_sorted.head()
# Out:
#    trial_id  pt_test_acc  pt_uniform_accuracy  pt_gaussian_accuracy  \
# 0  fe32ae60     0.980269             0.980071              0.980117
# 1  132ffee0     0.976167             0.975703              0.975749
# 2  8a7f6e40     0.970294             0.970002              0.970025
# 3  132e5d92     0.965700             0.964469              0.964631
# 4  3647d05c     0.968197             0.967295              0.967448
#
#    pt_saltandpepper_accuracy  pt_spatial_accuracy  tf_test_acc  \
# 0                   0.978531                  0.0       0.9801
# 1                   0.973801                  0.0       0.9759
# 2                   0.968126                  0.0       0.9692
# 3                   0.962392                  0.0       0.9694
# 4                   0.965058                  0.0       0.9656
#
#    tf_uniform_accuracy  tf_gaussian_accuracy  tf_saltandpepper_accuracy  ...  \
# 0             0.980289              0.980304                   0.978883  ...
# ...
