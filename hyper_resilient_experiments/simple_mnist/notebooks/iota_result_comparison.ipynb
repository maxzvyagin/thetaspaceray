# %%
import pandas as pd

# %%
first_res = pd.read_csv("../multi_model_multi_metric_results_50samples.csv")

# %%
second_res = pd.read_csv("../multi_model_multi_metric_results_50samples_iotagpu.csv")

# %%
first_res_sorted = first_res.sort_values('average_res', ascending=False)
first_res_sorted = first_res_sorted.reset_index(drop=True)

# %%
second_res_sorted = second_res.sort_values('average_res', ascending=False)
second_res_sorted = second_res_sorted.reset_index(drop=True)

# %%
first_res_sorted.head()
# Out:
#    trial_id  pt_test_acc  tf_test_acc  pt_uniform_accuracy  \
# 0  0e5929d2     0.998197       0.9811             0.994332
# 1  9151e550     0.996826       0.9795             0.993781
# 2  76371a10     0.998608       0.9805             0.989321
# 3  7638fede     0.996219       0.9772             0.989762
# 4  91524496     0.997467       0.9791             0.987692
#
#    tf_uniform_accuracy  pt_gaussian_accuracy  tf_gaussian_accuracy  \
# 0             1.000000              0.994939                   1.0
# 1             1.000000              0.992248                   1.0
# 2             1.000000              0.989502                   1.0
# 3             1.000000              0.990684                   1.0
# 4             0.999919              0.987692                   1.0
#
#    pt_saltandpepper_accuracy  tf_saltandpepper_accuracy  average_res  ...  \
# 0                   0.996761                   0.998785     0.995514  ...
# ...

# %%
second_res_sorted.head()
# Out:
#    trial_id  pt_test_acc  tf_test_acc  pt_uniform_accuracy  \
# 0  9e714238     0.996168       0.9773             0.997818
# 1  537770da     0.999585       0.9796             0.995716
# 2  056eb73c     0.998685       0.9787             0.993658
# 3  05756d20     0.996468       0.9760             0.991321
# 4  537b3f58     0.998800       0.9786             0.988513
#
#    tf_uniform_accuracy  pt_gaussian_accuracy  tf_gaussian_accuracy  \
# 0             1.000000              0.996545              1.000000
# 1             1.000000              0.994040              1.000000
# 2             0.998862              0.995446              0.999349
# 3             1.000000              0.990470              1.000000
# 4             1.000000              0.986667              1.000000
#
#    pt_saltandpepper_accuracy  tf_saltandpepper_accuracy  average_res  ...  \
# 0                   0.997454                   1.000000     0.995661  ...
# ...
